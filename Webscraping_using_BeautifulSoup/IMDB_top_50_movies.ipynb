# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
def top_50(url):
    res = requests.get(url)
    soup = BeautifulSoup(res.content, 'html.parser')
    movies = []
    for i in soup.find_all('td', class_ = 'titleColumn', limit = 50):
        movies.append(i.find('a').text)
    rating = []
    for i in soup.find_all('strong',limit = 50):
        rating.append(i.text)  
    year = []
    for i in soup.find_all('span', class_ = 'secondaryInfo', limit = 50):
        year.append(i.text.strip('()'))
    
    ind = []
    for i in range(1,51):
        ind.append(i)
    top_50_movies = pd.DataFrame({'Movie_Name':movies,'IMDB rating': rating, 'Year of Release': year}, index = ind)
    
    return top_50_movies

# %%
url = 'https://www.imdb.com/chart/top'
Movies = top_50(url)
Movies
# Out:
#                                            Movie_Name IMDB rating  \
# 1                            The Shawshank Redemption         9.2
# 2                                       The Godfather         9.2
# 3                                     The Dark Knight         9.0
# 4                               The Godfather Part II         9.0
# 5                                        12 Angry Men         9.0
# 6                                    Schindler's List         8.9
# 7       The Lord of the Rings: The Return of the King         8.9
# 8                                        Pulp Fiction         8.8
# 9   The Lord of the Rings: The Fellowship of the Ring         8.8
# 10                    Il buono, il brutto, il cattivo         8.8
# 11                                       Forrest Gump         8.8
# 12                                         Fight Club         8.7
# 13              The Lord of the Rings: The Two Towers         8.7
# 14                                          Inception         8.7
# 15                            The Empire Strikes Back         8.7
# 16                                         The Matrix         8.7
# 17                                         GoodFellas         8.7
# 18                    One Flew Over the Cuckoo's Nest         8.6
# 19                                              Se7en         8.6
# 20                               Shichinin no samurai         8.6
# 21                              It's a Wonderful Life         8.6
# 22                           The Silence of the Lambs         8.6
# 23                                Saving Private Ryan         8.6
# 24                                     Cidade de Deus         8.6
# 25                                       Interstellar         8.6
# 26                                    La vita è bella         8.6
# 27                                     The Green Mile         8.6
# 28                                          Star Wars         8.5
# 29                         Terminator 2: Judgment Day         8.5
# 30                                 Back to the Future         8.5
# 31                      Sen to Chihiro no kamikakushi         8.5
# 32                                        The Pianist         8.5
# 33                                             Psycho         8.5
# 34                                       Gisaengchung         8.5
# 35                                               Léon         8.5
# 36                                      The Lion King         8.5
# 37                                          Gladiator         8.5
# 38                                 American History X         8.5
# 39                                       The Departed         8.5
# 40                                       The Prestige         8.5
# 41                                           Whiplash         8.5
# 42                                 The Usual Suspects         8.5
# 43                                         Casablanca         8.5
# 44                                     Hotaru no haka         8.5
# 45                                            Seppuku         8.5
# 46                                   The Intouchables         8.5
# 47                                       Modern Times         8.4
# 48                       Once Upon a Time in the West         8.4
# 49                              Nuovo Cinema Paradiso         8.4
# 50                                        Rear Window         8.4
#
#    Year of Release
# 1             1994
# 2             1972
# 3             2008
# 4             1974
# 5             1957
# 6             1993
# 7             2003
# 8             1994
# 9             2001
# 10            1966
# 11            1994
# 12            1999
# 13            2002
# 14            2010
# 15            1980
# 16            1999
# 17            1990
# 18            1975
# 19            1995
# 20            1954
# 21            1946
# 22            1991
# 23            1998
# 24            2002
# 25            2014
# 26            1997
# 27            1999
# 28            1977
# 29            1991
# 30            1985
# 31            2001
# 32            2002
# 33            1960
# 34            2019
# 35            1994
# 36            1994
# 37            2000
# 38            1998
# 39            2006
# 40            2006
# 41            2014
# 42            1995
# 43            1942
# 44            1988
# 45            1962
# 46            2011
# 47            1936
# 48            1968
# 49            1988
# 50            1954
